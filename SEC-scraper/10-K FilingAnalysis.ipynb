# %% [markdown]
# ## Parsing Companies 10-K filings.
#
# After the daily-index scrape, we are now able to retrieve multiple types of filings. In this example, we will focus on one of the most important filing, the 10-K (Annual Report).
#
# ### Using Pandas
#
# We will be able to convert all tabular data contained in a 10-K to a pandas dataframe which will help us manipulate the information into what we need.

# %%
# import some libraries
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd

# %%
# defining a base url
base_url = r"https://www.sec.gov"

# from daily index, we get a file that looks like this
example = r"https://www.sec.gov/Archives/edgar/data/1652044/0001652044-22-000019.txt"

# we use an url that allows us to reach the 10-K reference page
documents_url = r"https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/index.json"

# Declaring user agent header for the content, this header is additional info passed to the request
headers = {'user-agent':'William',
          'Host':'www.sec.gov'}

# request and decode the documents url
content = requests.get(documents_url, headers=headers).json()

for file in content['directory']['item']:
    if file['name'] == 'FilingSummary.xml':
        
        xml_summary = base_url + content['directory']['name'] + '/' + file['name']
        
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/FilingSummary.xml

# %% [markdown]
# ### Now it's time to parse this xml file
#
# We notice that under the MyReports tag, there are multiple instances of reports along with information about them

# %%
# new base url for every report 
base_url = xml_summary.replace('FilingSummary.xml', '')

# request and parsing the xml file
content = requests.get(xml_summary, headers=headers).content
soup = BeautifulSoup(content, "html.parser")

# find the 'myreports' tag
reports = soup.find('myreports')

# store each individual report in a master list
master_list = []

# adding each report to the master list
for report in reports.find_all('report')[:-1]:
    # saving all the info we need in a dictionary
    report_info = {}
    report_info['name_short'] = report.shortname.text
    report_info['url'] = base_url + report.htmlfilename.text
    report_info['position'] = report.position.text
    report_info['name_long'] = report.longname.text
    report_info['category'] = report.menucategory.text
    
    # adding each report info to the master list
    master_list.append(report_info)
    
    # output to show urls and whats happening
    print('-' * 100)
    print("Short Name: " + report_info['name_short'])
    print("Long Name: " + report_info['name_long'])
    print("Category Type: " + report_info['category'])
    print("Position: " + report_info['position'])
    print("URL: " + report_info['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Short Name: Cover Page
# Long Name: 0001001 - Document - Cover Page
# Category Type: Cover
# Position: 1
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R1.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Audit Information
# Long Name: 0002002 - Document - Audit Information
# Category Type: Notes
# Position: 2
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R2.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED BALANCE SHEETS
# Long Name: 1001003 - Statement - CONSOLIDATED BALANCE SHEETS
# Category Type: Uncategorized
# Position: 3
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R3.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED BALANCE SHEETS (Parenthetical)
# Long Name: 1002004 - Statement - CONSOLIDATED BALANCE SHEETS (Parenthetical)
# Category Type: Cover
# Position: 4
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R4.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED STATEMENTS OF INCOME
# Long Name: 1003005 - Statement - CONSOLIDATED STATEMENTS OF INCOME
# Category Type: Statements
# Position: 5
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R5.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
# Long Name: 1004006 - Statement - CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
# Category Type: Statements
# Position: 6
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R6.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME (Parenthetical)
# Long Name: 1005007 - Statement - CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME (Parenthetical)
# Category Type: Statements
# Position: 7
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R7.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED STATEMENTS OF STOCKHOLDERS' EQUITY
# Long Name: 1006008 - Statement - CONSOLIDATED STATEMENTS OF STOCKHOLDERS' EQUITY
# Category Type: Statements
# Position: 8
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R8.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: CONSOLIDATED STATEMENTS OF CASH FLOWS
# Long Name: 1007009 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS
# Category Type: Statements
# Position: 9
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R9.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Summary of Significant Accounting Policies
# Long Name: 2101101 - Disclosure - Summary of Significant Accounting Policies
# Category Type: Notes
# Position: 10
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R10.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Revenues
# Long Name: 2104102 - Disclosure - Revenues
# Category Type: Notes
# Position: 11
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R11.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments
# Long Name: 2109103 - Disclosure - Financial Instruments
# Category Type: Notes
# Position: 12
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R12.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases
# Long Name: 2123104 - Disclosure - Leases
# Category Type: Notes
# Position: 13
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R13.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Variable Interest Entities
# Long Name: 2129105 - Disclosure - Variable Interest Entities
# Category Type: Notes
# Position: 14
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R14.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Debt
# Long Name: 2131106 - Disclosure - Debt
# Category Type: Notes
# Position: 15
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R15.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information
# Long Name: 2136107 - Disclosure - Supplemental Financial Statement Information
# Category Type: Notes
# Position: 16
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R16.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Acquisitions
# Long Name: 2143108 - Disclosure - Acquisitions
# Category Type: Notes
# Position: 17
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R17.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets
# Long Name: 2145109 - Disclosure - Goodwill and Other Intangible Assets
# Category Type: Notes
# Position: 18
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R18.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Contingencies
# Long Name: 2151110 - Disclosure - Contingencies
# Category Type: Notes
# Position: 19
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R19.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Stockholders' Equity
# Long Name: 2153111 - Disclosure - Stockholders' Equity
# Category Type: Notes
# Position: 20
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R20.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Net Income Per Share
# Long Name: 2155112 - Disclosure - Net Income Per Share
# Category Type: Notes
# Position: 21
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R21.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans
# Long Name: 2158113 - Disclosure - Compensation Plans
# Category Type: Notes
# Position: 22
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R22.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes
# Long Name: 2164114 - Disclosure - Income Taxes
# Category Type: Notes
# Position: 23
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R23.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Information about Segments and Geographic Areas
# Long Name: 2172115 - Disclosure - Information about Segments and Geographic Areas
# Category Type: Notes
# Position: 24
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R24.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Schedule II: Valuation and Qualifying Accounts
# Long Name: 2176116 - Disclosure - Schedule II: Valuation and Qualifying Accounts
# Category Type: Notes
# Position: 25
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R25.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Summary of Significant Accounting Policies (Policies)
# Long Name: 2202201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Category Type: Policies
# Position: 26
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R26.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Revenues (Tables)
# Long Name: 2305301 - Disclosure - Revenues (Tables)
# Category Type: Tables
# Position: 27
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R27.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Tables)
# Long Name: 2310302 - Disclosure - Financial Instruments (Tables)
# Category Type: Tables
# Position: 28
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R28.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases (Tables)
# Long Name: 2324303 - Disclosure - Leases (Tables)
# Category Type: Tables
# Position: 29
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R29.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Debt (Tables)
# Long Name: 2332304 - Disclosure - Debt (Tables)
# Category Type: Tables
# Position: 30
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R30.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Tables)
# Long Name: 2337305 - Disclosure - Supplemental Financial Statement Information (Tables)
# Category Type: Tables
# Position: 31
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R31.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets (Tables)
# Long Name: 2346306 - Disclosure - Goodwill and Other Intangible Assets (Tables)
# Category Type: Tables
# Position: 32
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R32.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Net Income Per Share (Tables)
# Long Name: 2356307 - Disclosure - Net Income Per Share (Tables)
# Category Type: Tables
# Position: 33
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R33.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans (Tables)
# Long Name: 2359308 - Disclosure - Compensation Plans (Tables)
# Category Type: Tables
# Position: 34
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R34.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Tables)
# Long Name: 2365309 - Disclosure - Income Taxes (Tables)
# Category Type: Tables
# Position: 35
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R35.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Information about Segments and Geographic Areas (Tables)
# Long Name: 2373310 - Disclosure - Information about Segments and Geographic Areas (Tables)
# Category Type: Tables
# Position: 36
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R36.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Summary of Significant Accounting Policies (Narrative) (Details)
# Long Name: 2403401 - Disclosure - Summary of Significant Accounting Policies (Narrative) (Details)
# Category Type: Details
# Position: 37
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R37.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Revenues (Revenue by Segment) (Details)
# Long Name: 2406402 - Disclosure - Revenues (Revenue by Segment) (Details)
# Category Type: Details
# Position: 38
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R38.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Revenues (Revenue by Geographic Location) (Details)
# Long Name: 2407403 - Disclosure - Revenues (Revenue by Geographic Location) (Details)
# Category Type: Details
# Position: 39
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R39.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Revenues (Narrative) (Details)
# Long Name: 2408404 - Disclosure - Revenues (Narrative) (Details)
# Category Type: Details
# Position: 40
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R40.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Narrative) (Details)
# Long Name: 2411405 - Disclosure - Financial Instruments (Narrative) (Details)
# Category Type: Details
# Position: 41
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R41.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Debt Securities) (Details)
# Long Name: 2412406 - Disclosure - Financial Instruments (Debt Securities) (Details)
# Category Type: Details
# Position: 42
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R42.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Contractual Maturity Date of Marketable Debt Securities) (Details)
# Long Name: 2413407 - Disclosure - Financial Instruments (Contractual Maturity Date of Marketable Debt Securities) (Details)
# Category Type: Details
# Position: 43
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R43.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Gross Unrealized Losses and Fair Values for Investments in Unrealized Loss Position) (Details)
# Long Name: 2414408 - Disclosure - Financial Instruments (Gross Unrealized Losses and Fair Values for Investments in Unrealized Loss Position) (Details)
# Category Type: Details
# Position: 44
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R44.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Gains and Losses on Equity Securities) (Details)
# Long Name: 2415409 - Disclosure - Financial Instruments (Gains and Losses on Equity Securities) (Details)
# Category Type: Details
# Position: 45
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R45.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Carrying Amount of Equity Securities) (Details)
# Long Name: 2416410 - Disclosure - Financial Instruments (Carrying Amount of Equity Securities) (Details)
# Category Type: Details
# Position: 46
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R46.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Marketable Equity Securities) (Details)
# Long Name: 2417411 - Disclosure - Financial Instruments (Marketable Equity Securities) (Details)
# Category Type: Details
# Position: 47
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R47.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Non-Marketable Equity Securities) (Details)
# Long Name: 2418412 - Disclosure - Financial Instruments (Non-Marketable Equity Securities) (Details)
# Category Type: Details
# Position: 48
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R48.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Derivative Notional Amounts) (Details)
# Long Name: 2419413 - Disclosure - Financial Instruments (Derivative Notional Amounts) (Details)
# Category Type: Details
# Position: 49
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R49.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Fair Values of Outstanding Derivative Instruments) (Details)
# Long Name: 2420414 - Disclosure - Financial Instruments (Fair Values of Outstanding Derivative Instruments) (Details)
# Category Type: Details
# Position: 50
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R50.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Effect of Derivative Instruments on Income and Accumulated Other Comprehensive Income) (Details)
# Long Name: 2421415 - Disclosure - Financial Instruments (Effect of Derivative Instruments on Income and Accumulated Other Comprehensive Income) (Details)
# Category Type: Details
# Position: 51
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R51.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Financial Instruments (Offsetting of Financial Assets and Financial Liabilities) (Details)
# Long Name: 2422416 - Disclosure - Financial Instruments (Offsetting of Financial Assets and Financial Liabilities) (Details)
# Category Type: Details
# Position: 52
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R52.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases (Components of Operating Lease Expense) (Details)
# Long Name: 2425417 - Disclosure - Leases (Components of Operating Lease Expense) (Details)
# Category Type: Details
# Position: 53
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R53.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases (Supplemental Cash Flow Information) (Details)
# Long Name: 2426418 - Disclosure - Leases (Supplemental Cash Flow Information) (Details)
# Category Type: Details
# Position: 54
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R54.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases (Narrative) (Details)
# Long Name: 2427419 - Disclosure - Leases (Narrative) (Details)
# Category Type: Details
# Position: 55
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R55.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Leases (Future Minimum Lease Payments) (Details)
# Long Name: 2428420 - Disclosure - Leases (Future Minimum Lease Payments) (Details)
# Category Type: Details
# Position: 56
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R56.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Variable Interest Entities (Narrative) (Details)
# Long Name: 2430421 - Disclosure - Variable Interest Entities (Narrative) (Details)
# Category Type: Details
# Position: 57
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R57.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Debt (Narrative) (Details)
# Long Name: 2433422 - Disclosure - Debt (Narrative) (Details)
# Category Type: Details
# Position: 58
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R58.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Debt (Long-Term Debt) (Details)
# Long Name: 2434423 - Disclosure - Debt (Long-Term Debt) (Details)
# Category Type: Details
# Position: 59
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R59.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Debt (Future Principal Payments for Borrowings) (Details)
# Long Name: 2435424 - Disclosure - Debt (Future Principal Payments for Borrowings) (Details)
# Category Type: Details
# Position: 60
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R60.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Property and Equipment) (Details)
# Long Name: 2438425 - Disclosure - Supplemental Financial Statement Information (Property and Equipment) (Details)
# Category Type: Details
# Position: 61
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R61.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Accrued Expenses and Other Current Liabilities) (Details)
# Long Name: 2439426 - Disclosure - Supplemental Financial Statement Information (Accrued Expenses and Other Current Liabilities) (Details)
# Category Type: Details
# Position: 62
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R62.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Components of Accumulated Other Comprehensive Income) (Details)
# Long Name: 2440427 - Disclosure - Supplemental Financial Statement Information (Components of Accumulated Other Comprehensive Income) (Details)
# Category Type: Details
# Position: 63
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R63.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Reclassifications Out of Accumulated Other Comprehensive Income (Loss)) (Details)
# Long Name: 2441428 - Disclosure - Supplemental Financial Statement Information (Reclassifications Out of Accumulated Other Comprehensive Income (Loss)) (Details)
# Category Type: Details
# Position: 64
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R64.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Supplemental Financial Statement Information (Components of Other Income (Expense), Net) (Details)
# Long Name: 2442429 - Disclosure - Supplemental Financial Statement Information (Components of Other Income (Expense), Net) (Details)
# Category Type: Details
# Position: 65
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R65.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Acquisitions (Narrative) (Details)
# Long Name: 2444430 - Disclosure - Acquisitions (Narrative) (Details)
# Category Type: Details
# Position: 66
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R66.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets (Changes in Carrying Amount of Goodwill) (Details)
# Long Name: 2447431 - Disclosure - Goodwill and Other Intangible Assets (Changes in Carrying Amount of Goodwill) (Details)
# Category Type: Details
# Position: 67
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R67.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets (Acquisition-Related Intangible Assets that are being Amortized) (Details)
# Long Name: 2448432 - Disclosure - Goodwill and Other Intangible Assets (Acquisition-Related Intangible Assets that are being Amortized) (Details)
# Category Type: Details
# Position: 68
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R68.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets (Narrative) (Details)
# Long Name: 2449433 - Disclosure - Goodwill and Other Intangible Assets (Narrative) (Details)
# Category Type: Details
# Position: 69
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R69.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Goodwill and Other Intangible Assets (Expected Amortization Expense for Acquisition-Related Intangible Assets) (Details)
# Long Name: 2450434 - Disclosure - Goodwill and Other Intangible Assets (Expected Amortization Expense for Acquisition-Related Intangible Assets) (Details)
# Category Type: Details
# Position: 70
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R70.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Commitments and Contingencies (Narrative) (Details)
# Long Name: 2452435 - Disclosure - Commitments and Contingencies (Narrative) (Details)
# Category Type: Details
# Position: 71
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R71.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Stockholders' Equity (Narrative) (Details)
# Long Name: 2454436 - Disclosure - Stockholders' Equity (Narrative) (Details)
# Category Type: Details
# Position: 72
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R72.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Net Income Per Share (Schedule of Earnings Per Share) (Details)
# Long Name: 2457437 - Disclosure - Net Income Per Share (Schedule of Earnings Per Share) (Details)
# Category Type: Details
# Position: 73
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R73.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans (Stock Plans) (Details)
# Long Name: 2460438 - Disclosure - Compensation Plans (Stock Plans) (Details)
# Category Type: Details
# Position: 74
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R74.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans (Stock Based Compensation) (Details)
# Long Name: 2461439 - Disclosure - Compensation Plans (Stock Based Compensation) (Details)
# Category Type: Details
# Position: 75
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R75.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans (Stock Based Award Activities) (Details)
# Long Name: 2462440 - Disclosure - Compensation Plans (Stock Based Award Activities) (Details)
# Category Type: Details
# Position: 76
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R76.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Compensation Plans (401k Plans and Performance Fees) (Details)
# Long Name: 2463441 - Disclosure - Compensation Plans (401k Plans and Performance Fees) (Details)
# Category Type: Details
# Position: 77
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R77.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Income From Continuing Operations Before Income Taxes) (Details)
# Long Name: 2466442 - Disclosure - Income Taxes (Income From Continuing Operations Before Income Taxes) (Details)
# Category Type: Details
# Position: 78
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R78.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Provision for Income Taxes) (Details)
# Long Name: 2467443 - Disclosure - Income Taxes (Provision for Income Taxes) (Details)
# Category Type: Details
# Position: 79
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R79.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Reconciliation of Federal Statutory Income Tax Rate to Effective Income Tax Rate) (Details)
# Long Name: 2468444 - Disclosure - Income Taxes (Reconciliation of Federal Statutory Income Tax Rate to Effective Income Tax Rate) (Details)
# Category Type: Details
# Position: 80
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R80.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Narrative) (Details)
# Long Name: 2469445 - Disclosure - Income Taxes (Narrative) (Details)
# Category Type: Details
# Position: 81
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R81.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Significant Components of Deferred Tax Assets and Liabilities) (Details)
# Long Name: 2470446 - Disclosure - Income Taxes (Significant Components of Deferred Tax Assets and Liabilities) (Details)
# Category Type: Details
# Position: 82
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R82.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Income Taxes (Summary of Activity Related to Gross Unrecognized Tax Benefits) (Details)
# Long Name: 2471447 - Disclosure - Income Taxes (Summary of Activity Related to Gross Unrecognized Tax Benefits) (Details)
# Category Type: Details
# Position: 83
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R83.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Information about Segments and Geographic Areas (Revenue and Operating Income/Loss by Segment) (Details)
# Long Name: 2474448 - Disclosure - Information about Segments and Geographic Areas (Revenue and Operating Income/Loss by Segment) (Details)
# Category Type: Details
# Position: 84
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R84.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Information about Segments and Geographic Areas (Long-Lived Assets by Geographic Area) (Details)
# Long Name: 2475449 - Disclosure - Information about Segments and Geographic Areas (Long-Lived Assets by Geographic Area) (Details)
# Category Type: Details
# Position: 85
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R85.htm
# ----------------------------------------------------------------------------------------------------
# Short Name: Schedule II: Valuation and Qualifying Accounts (Details)
# Long Name: 2477450 - Disclosure - Schedule II: Valuation and Qualifying Accounts (Details)
# Category Type: Details
# Position: 86
# URL: https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R86.htm

# %% [markdown]
# ### Let's convert the information in these reports to dataframes
#
# We have parsed the FilingSummary xml file to retrieve all the reports.
# Now it is time to go through those reports and save the information we want.

# %%
# save all important statements into another list
statements_url = []

for report in master_list:
    # list of statement names
    item1 = r"Consolidated Balance Sheets"
    item2 = r"Consolidated Statements of Operations and Comprehensive Income (Loss)"
    item3 = r"Consolidated Statements of Cash Flows"
    item4 = r"Consolidated Statements of Stockholder's (Deficit) Equity"
    
    # store the items into a list
    search_list = [item1.upper(), item2.upper(), item3.upper(), item4.upper()]
    
    # look if the report.shortname is in the list
    if report['name_short'] in search_list:
        
        # output information
        print('-' * 100)
        print(report['name_short'])
        print(report['url'])
        
        # add report to the statements url list
        statements_url.append(report['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# CONSOLIDATED BALANCE SHEETS
# https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R3.htm
# ----------------------------------------------------------------------------------------------------
# CONSOLIDATED STATEMENTS OF CASH FLOWS
# https://www.sec.gov/Archives/edgar/data/1652044/000165204422000019/R9.htm

# %%
# creating a dataset, with a list of data, headers and sections
statements_data = []

# looping through each statement
for statement in statements_url:
    
    # create a dictionary to store the content of each statement
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the content and parse it with BeautifulSoup
    content = requests.get(statement, headers=headers).content
    report_soup = BeautifulSoup(content, "html")
    
    # loop through the soup and retrieve the data
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first we get all the elements
        cols = row.find_all('td')
        
        # detect difference between regular rows, sections and table headers
        if len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0:
            
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
                                               
        # if strong but not th, we know it will be a section
        elif len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0:   
             
            section_row = cols[0].text.strip()
            statement_data['sections'].append(section_row)
                                               
        # else we know it will be header since th is present but not strong
        elif len(row.find_all('th')) != 0:
            
            header_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(header_row)
                                               
        # this should only trigger when an error occurred
        else:
            print("an error occured on this row")
    
    # append data to master list
    statements_data.append(statement_data)

# outpute the statements_data
statements_data
# Out:
# [{'headers': [['CONSOLIDATED BALANCE SHEETS - USD ($) $ in Millions',
#     'Dec. 31, 2021',
#     'Dec. 31, 2020']],
#   'sections': ['Current assets:',
#    'Current liabilities:',
#    'Stockholders’ equity:'],
#   'data': [['Cash and cash equivalents', '$ 20,945', '$ 26,465'],
#    ['Marketable securities', '118,704', '110,229'],
#    ['Total cash, cash equivalents, and marketable securities',
#     '139,649',
#     '136,694'],
#    ['Accounts receivable, net', '39,304', '30,930'],
#    ['Income taxes receivable, net', '966', '454'],
#    ['Inventory', '1,170', '728'],
#    ['Other current assets', '7,054', '5,490'],
#    ['Total current assets', '188,143', '174,296'],
#    ['Non-marketable securities', '29,549', '20,703'],
#    ['Deferred income taxes', '1,284', '1,084'],
#    ['Property and equipment, net', '97,599', '84,749'],
#    ['Operating lease assets', '12,959', '12,211'],
#    ['Intangible assets, net', '1,417', '1,445'],
#    ['Goodwill', '22,956', '21,175'],
#    ['Other non-current assets', '5,361', '3,953'],
#    ['Total assets', '359,268', '319,616'],
#    ['Accounts payable', '6,037', '5,589'],
#    ['Accrued compensation and benefits', '13,889', '11,086'],
#    ['Accrued expenses and other current liabilities', '31,236', '28,631'],
#    ['Accrued revenue share', '8,996', '7,500'],
#    ['Deferred revenue', '3,288', '2,543'],
#    ['Income taxes payable, net', '808', '1,485'],
#    ['Total current liabilities', '64,254', '56,834'],
#    ['Long-term debt', '14,817', '13,932'],
#    ['Deferred revenue, non-current', '535', '481'],
#    ['Income taxes payable, non-current', '9,176', '8,849'],
#    ['Deferred income taxes', '5,257', '3,561'],
#    ['Operating lease liabilities', '11,389', '11,146'],
#    ['Other long-term liabilities', '2,205', '2,269'],
#    ['Total liabilities', '107,633', '97,072'],
#    ['Contingencies (Note 10)', '', ''],
#    ['Preferred stock, $0.001 par value per share, 100,000 shares authorized; no shares issued and outstanding',
#     '0',
#     '0'],
#    ['Class\xa0A and Class B common stock, and Class C capital stock and additional paid-in capital, $0.001 par value per share: 15,000,000 shares authorized\xa0(Class\xa0A 9,000,000, Class B 3,000,000, Class C 3,000,000); 675,222 (Class\xa0A 300,730, Class B 45,843, Class C 328,649) and 662,121 (Class\xa0A 300,737, Class B 44,665, Class C 316,719) shares issued and outstanding',
#     '61,774',
#     '58,510'],
#    ['Accumulated other comprehensive income (loss)', '(1,623)', '633'],
#    ['Retained earnings', '191,484', '163,401'],
#    ['Total stockholders’ equity', '251,635', '222,544'],
#    ['Total liabilities and stockholders’ equity', '$ 359,268', '$ 319,616']]},
#  {'headers': [['CONSOLIDATED STATEMENTS OF CASH FLOWS - USD ($) $ in Millions',
#     '12 Months Ended'],
#    ['Dec. 31, 2021', 'Dec. 31, 2020', 'Dec. 31, 2019']],
#   'sections': ['Operating activities',
#    'Adjustments:',
#    'Changes in assets and liabilities, net of effects of acquisitions:',
#    'Investing activities',
#    'Financing activities',
#    'Supplemental disclosures of cash flow information'],
#   'data': [['Net income', '$ 76,033', '$ 40,269', '$ 34,343'],
#    ['Depreciation and impairment of property and equipment',
#     '11,555',
#     '12,905',
#     '10,856'],
#    ['Amortization and impairment of intangible assets', '886', '792', '925'],
#    ['Stock-based compensation expense', '15,376', '12,991', '10,794'],
#    ['Deferred income taxes', '1,808', '1,390', '173'],
#    ['Gain on debt and equity securities, net',
#     '(12,270)',
#     '(6,317)',
#     '(2,798)'],
#    ['Other', '(213)', '1,267', '(592)'],
#    ['Accounts receivable', '(9,095)', '(6,524)', '(4,340)'],
#    ['Income taxes, net', '(625)', '1,209', '(3,128)'],
#    ['Other assets', '(1,846)', '(1,330)', '(621)'],
#    ['Accounts payable', '283', '694', '428'],
#    ['Accrued expenses and other liabilities', '7,304', '5,504', '7,170'],
#    ['Accrued revenue share', '1,682', '1,639', '1,273'],
#    ['Deferred revenue', '774', '635', '37'],
#    ['Net cash provided by operating activities', '91,652', '65,124', '54,520'],
#    ['Purchases of property and equipment', '(24,640)', '(22,281)', '(23,548)'],
#    ['Purchases of marketable securities',
#     '(135,196)',
#     '(136,576)',
#     '(100,315)'],
#    ['Maturities and sales of marketable securities',
#     '128,294',
#     '132,906',
#     '97,825'],
#    ['Purchases of non-marketable securities', '(2,838)', '(7,175)', '(1,932)'],
#    ['Maturities and sales of non-marketable securities',
#     '934',
#     '1,023',
#     '405'],
#    ['Acquisitions, net of cash acquired, and purchases of intangible assets',
#     '(2,618)',
#     '(738)',
#     '(2,515)'],
#    ['Other investing activities', '541', '68', '589'],
#    ['Net cash used in investing activities',
#     '(35,523)',
#     '(32,773)',
#     '(29,491)'],
#    ['Net payments related to stock-based award activities',
#     '(10,162)',
#     '(5,720)',
#     '(4,765)'],
#    ['Repurchases of common and capital stock',
#     '(50,274)',
#     '(31,149)',
#     '(18,396)'],
#    ['Proceeds from issuance of debt, net of costs', '20,199', '11,761', '317'],
#    ['Repayments of debt', '(21,435)', '(2,100)', '(585)'],
#    ['Proceeds from sale of interest in consolidated entities, net',
#     '310',
#     '2,800',
#     '220'],
#    ['Net cash used in financing activities',
#     '(61,362)',
#     '(24,408)',
#     '(23,209)'],
#    ['Effect of exchange rate changes on cash and cash equivalents',
#     '(287)',
#     '24',
#     '(23)'],
#    ['Net increase (decrease) in cash and cash equivalents',
#     '(5,520)',
#     '7,967',
#     '1,797'],
#    ['Cash and cash equivalents at beginning of period',
#     '26,465',
#     '18,498',
#     '16,701'],
#    ['Cash and cash equivalents at end of period',
#     '20,945',
#     '26,465',
#     '18,498'],
#    ['Cash paid for income taxes, net of refunds',
#     '$ 13,412',
#     '$ 4,990',
#     '$ 8,203']]}]

# %% [markdown]
# ### Now we convert to DataFrame
#
# Essentially in statements_data we currently have all the table information for each statement and we have properly separated the rows into the data, headers and sections.
#
# Now we can convert the data into a dataframe which will allow us flexibility in potential visualizations or further manipulations

# %%
# grab the components we want
income_headers = statements_data[1]['headers'][1]
income_data = statements_data[1]['data']

# save data into a df
income_df = pd.DataFrame(income_data)

# display before reindex
print('-' * 100)
print('Before Reindexing')
print('-' * 100)
display(income_df.head(5))

# Drop the old index and define a new one
income_df.index = income_df[0]
income_df.index.name = 'Category'
income_df = income_df.drop(0, axis = 1)

# display before regex
print('-' * 100)
print('Before Regex Matching')
print('-' * 100)
display(income_df.head(5))

# Converting data to string and removing negatives and nulls
income_df = income_df.replace('[\$,)]', '', regex = True)\
                     .replace('[(]', '-', regex = True)\
                     .replace('', 'NaN', regex = True)

# Convert the data from string to float
income_df = income_df.astype(float)

# Replace the headers with the income headers
income_df.columns = income_headers

# Display of final results
print('-' * 100)
print('Final Product')
print('-' * 100)
display(income_df.head(5))
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                                    0         1         2  \
# 0                                         Net income  $ 76,033  $ 40,269
# 1  Depreciation and impairment of property and eq...    11,555    12,905
# 2   Amortization and impairment of intangible assets       886       792
# 3                   Stock-based compensation expense    15,376    12,991
# 4                              Deferred income taxes     1,808     1,390
#
#           3
# 0  $ 34,343
# 1    10,856
# 2       925
# 3    10,794
# 4       173
# ----------------------------------------------------------------------------------------------------
# Before Regex Matching
# ----------------------------------------------------------------------------------------------------
#                                                            1         2  \
# Category
# Net income                                          $ 76,033  $ 40,269
# Depreciation and impairment of property and equ...    11,555    12,905
# Amortization and impairment of intangible assets         886       792
# Stock-based compensation expense                      15,376    12,991
# Deferred income taxes                                  1,808     1,390
#
#                                                            3
# Category
# Net income                                          $ 34,343
# Depreciation and impairment of property and equ...    10,856
# Amortization and impairment of intangible assets         925
# Stock-based compensation expense                      10,794
# Deferred income taxes                                    173
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                     Dec. 31, 2021  \
# Category
# Net income                                                76033.0
# Depreciation and impairment of property and equ...        11555.0
# Amortization and impairment of intangible assets            886.0
# Stock-based compensation expense                          15376.0
# Deferred income taxes                                      1808.0
#
#                                                     Dec. 31, 2020  \
# Category
# Net income                                                40269.0
# Depreciation and impairment of property and equ...        12905.0
# Amortization and impairment of intangible assets            792.0
# Stock-based compensation expense                          12991.0
# Deferred income taxes                                      1390.0
#
#                                                     Dec. 31, 2019
# Category
# Net income                                                34343.0
# Depreciation and impairment of property and equ...        10856.0
# Amortization and impairment of intangible assets            925.0
# Stock-based compensation expense                          10794.0
# Deferred income taxes                                       173.0
